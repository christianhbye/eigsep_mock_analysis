# %%
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp
from pygdsm import GlobalSkyModel16

# %matplotlib widget

# %%
cfb = np.load("/home/christian/Documents/projects/cryofunk/cryofab_basis.npz")
ell_cfb = cfb["ell"]
basis = cfb["basis"]

# %%
h = np.load("/home/christian/Documents/projects/cryofunk/horizon.npz")
h = h["horizon"]

# %%
np.sum(h)
# Out:
# 1116
